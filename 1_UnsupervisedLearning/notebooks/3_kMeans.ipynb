# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %% [markdown]
# ## Importing File

# %%
features = pd.read_csv("../data/03_selected/clustering_features_with_target.csv")
X = features.drop("target", axis=1)
y = features["target"]

# %% [markdown]
# ## K-Means

# %%
K_range = range(2, 11)
inertias = []
scores = []

for k in K_range:
    kmeans = KMeans(n_clusters=k, n_init= 10, random_state=42)
    kmeans.fit(X)
    
    inertias.append(kmeans.inertia_)

    silhouette = silhouette_score(X, kmeans.labels_)
    scores.append(silhouette)

# %% [markdown]
# ## Graphs

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 5))

ax1.plot(list(K_range), inertias)
ax1.set_xlabel("k")
ax1.set_ylabel("Inertia")
ax1.set_title("Elbow Method")


ax2.plot(list(K_range), scores)
ax2.set_xlabel("k")
ax2.set_ylabel("Silhouette Score")
ax2.set_title("Silhouette Score")


plt.show()

# %% [markdown]
# The optimal K to use according to the Silhouette score is 2, however according to the elbow it could be 3. We chose k = 2 as the target is disease or no disease.

# %% [markdown]
# ## PCA

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# %% [markdown]
# ## Final model with PCA visualization

# %%
k = 2
km_final = KMeans(n_clusters=k, n_init=10, random_state=42)
km_final.fit(X)          
labels = km_final.labels_

plt.figure(figsize=(8, 6))
for c in range(k):
    mask = labels == c
    plt.scatter(X_pca[mask, 0], X_pca[mask, 1], alpha=0.5, s=45,
                label=f"Cluster {c} (n={mask.sum()})")

centroids_pca = pca.transform(km_final.cluster_centers_)
plt.scatter(centroids_pca[:, 0], centroids_pca[:, 1],
            c="black", marker="X", s=200, label="Centroids")

plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("K-Means PCA Projection")
plt.legend()
plt.show()
# Out:
# /Users/mac/miniconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but PCA was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Centroids

# %%
centres = pd.DataFrame(
    km_final.cluster_centers_,
    columns=X.columns
)
print(centres.round(3))
# Out:
#    thalach  oldpeak     ca   cp_4  is_exang  thal_3  thal_7
# 0   -0.409    0.451  0.376  0.446     0.423  -1.000   0.936
# 1    0.347   -0.382 -0.319 -0.378    -0.359   0.847  -0.793

# %% [markdown]
# The main feature in cluster 0 is exang_1 while for cluster 1 is thalach and the minimum for cluster 0 is thalach  and the minimum for cluster 1 is exang_1

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

flipped_labels = 1 - km_final.labels_

cm = confusion_matrix(y, flipped_labels)
ConfusionMatrixDisplay(cm, display_labels=["No Disease", "Disease"]).plot()
plt.xlabel("K-Means")
plt.ylabel("True Label")
plt.show()

# %% [markdown]
# ## ARI Score

# %%
from sklearn.metrics import adjusted_rand_score

ari = adjusted_rand_score(y, km_final.labels_)
print(f"Adjusted Rand Index: {ari:.4f}")
# Out:
# Adjusted Rand Index: 0.3627
